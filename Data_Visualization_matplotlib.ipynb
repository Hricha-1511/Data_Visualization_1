# %% [markdown]
# # DATA VISUALIZATION

# %% [markdown]
#  Data Visualization (DataViz) is the process of generating graphical representations of data for various purposes. These graphical representations are commonly known as plots or charts in data science terminology.

# %% [markdown]
# -->Review the python visualization landscape
# -->Explore core visualization concepts
# -->Use matplotlib to build and customize visualizations
# -->Build and customize simple plots with pandas
# -->Learn about seaborn and use it for statistical visualizations

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
from matplotlib import ticker
import statsmodels.formula.api as smf

# %%
df=pd.read_csv("vehicles.csv")
# Out:
# C:\Users\Hricha\AppData\Local\Temp\ipykernel_3532\17828067.py:1: DtypeWarning: Columns (70,71,72,73,74,76,79) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("vehicles.csv")

# %%
df
# Out:
#        barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0      14.167143         0.0        0.0        0.0      19      0.0        0
# 1      27.046364         0.0        0.0        0.0       9      0.0        0
# 2      11.018889         0.0        0.0        0.0      23      0.0        0
# 3      27.046364         0.0        0.0        0.0      10      0.0        0
# 4      15.658421         0.0        0.0        0.0      17      0.0        0
# ...          ...         ...        ...        ...     ...      ...      ...
# 46019  13.523182         0.0        0.0        0.0      19      0.0        0
# 46020  12.935217         0.0        0.0        0.0      20      0.0        0
# 46021  14.167143         0.0        0.0        0.0      18      0.0        0
# 46022  14.167143         0.0        0.0        0.0      18      0.0        0
# 46023  16.528333         0.0        0.0        0.0      16      0.0        0
#
#        cityA08U  cityCD  cityE  ...  mfrCode  c240Dscr  charge240b  c240bDscr  \
# 0           0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 1           0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 2           0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 3           0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 4           0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# ...         ...     ...    ...  ...      ...       ...         ...        ...
# 46019       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 46020       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 46021       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 46022       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 46023       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
#
#                           createdOn                    modifiedOn  startStop  \
# 0      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 1      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 2      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 3      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 4      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# ...                             ...                           ...        ...
# 46019  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 46020  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 46021  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 46022  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 46023  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
#
#        phevCity  phevHwy  phevComb
# 0             0        0         0
# 1             0        0         0
# 2             0        0         0
# 3             0        0         0
# 4             0        0         0
# ...         ...      ...       ...
# 46019         0        0         0
# 46020         0        0         0
# 46021         0        0         0
# 46022         0        0         0
# 46023         0        0         0
#
# [46024 rows x 83 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46024 entries, 0 to 46023
# Data columns (total 83 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   barrels08        46024 non-null  float64
#  1   barrelsA08       46024 non-null  float64
#  2   charge120        46024 non-null  float64
#  3   charge240        46024 non-null  float64
#  4   city08           46024 non-null  int64
#  5   city08U          46024 non-null  float64
#  6   cityA08          46024 non-null  int64
#  7   cityA08U         46024 non-null  float64
#  8   cityCD           46024 non-null  float64
#  9   cityE            46024 non-null  float64
#  10  cityUF           46024 non-null  float64
#  11  co2              46024 non-null  int64
#  12  co2A             46024 non-null  int64
#  13  co2TailpipeAGpm  46024 non-null  float64
#  14  co2TailpipeGpm   46024 non-null  float64
#  15  comb08           46024 non-null  int64
#  16  comb08U          46024 non-null  float64
#  17  combA08          46024 non-null  int64
#  18  combA08U         46024 non-null  float64
#  19  combE            46024 non-null  float64
#  20  combinedCD       46024 non-null  float64
#  21  combinedUF       46024 non-null  float64
#  22  cylinders        45537 non-null  float64
#  23  displ            45539 non-null  float64
#  24  drive            44838 non-null  object
#  25  engId            46024 non-null  int64
#  26  eng_dscr         28976 non-null  object
#  27  feScore          46024 non-null  int64
#  28  fuelCost08       46024 non-null  int64
#  29  fuelCostA08      46024 non-null  int64
#  30  fuelType         46024 non-null  object
#  31  fuelType1        46024 non-null  object
#  32  ghgScore         46024 non-null  int64
#  33  ghgScoreA        46024 non-null  int64
#  34  highway08        46024 non-null  int64
#  35  highway08U       46024 non-null  float64
#  36  highwayA08       46024 non-null  int64
#  37  highwayA08U      46024 non-null  float64
#  38  highwayCD        46024 non-null  float64
#  39  highwayE         46024 non-null  float64
#  40  highwayUF        46024 non-null  float64
#  41  hlv              46024 non-null  int64
#  42  hpv              46024 non-null  int64
#  43  id               46024 non-null  int64
#  44  lv2              46024 non-null  int64
#  45  lv4              46024 non-null  int64
#  46  make             46024 non-null  object
#  47  model            46024 non-null  object
#  48  mpgData          46017 non-null  object
#  49  phevBlended      46024 non-null  bool
#  50  pv2              46024 non-null  int64
#  51  pv4              46024 non-null  int64
#  52  range            46024 non-null  int64
#  53  rangeCity        46024 non-null  float64
#  54  rangeCityA       46024 non-null  float64
#  55  rangeHwy         46024 non-null  float64
#  56  rangeHwyA        46024 non-null  float64
#  57  trany            46013 non-null  object
#  58  UCity            46024 non-null  float64
#  59  UCityA           46024 non-null  float64
#  60  UHighway         46024 non-null  float64
#  61  UHighwayA        46024 non-null  float64
#  62  VClass           46024 non-null  object
#  63  year             46024 non-null  int64
#  64  youSaveSpend     46024 non-null  int64
#  65  guzzler          2701 non-null   object
#  66  trans_dscr       15044 non-null  object
#  67  tCharger         9575 non-null   object
#  68  sCharger         990 non-null    object
#  69  atvType          4678 non-null   object
#  70  fuelType2        1838 non-null   object
#  71  rangeA           1833 non-null   object
#  72  evMotor          1826 non-null   object
#  73  mfrCode          15216 non-null  object
#  74  c240Dscr         141 non-null    object
#  75  charge240b       46024 non-null  float64
#  76  c240bDscr        135 non-null    object
#  77  createdOn        46024 non-null  object
#  78  modifiedOn       46024 non-null  object
#  79  startStop        14335 non-null  object
#  80  phevCity         46024 non-null  int64
#  81  phevHwy          46024 non-null  int64
#  82  phevComb         46024 non-null  int64
# dtypes: bool(1), float64(32), int64(27), object(23)
# memory usage: 28.8+ MB

# %%
import matplotlib.image as mpimg
from matplotlib.patches import Rectangle
from matplotlib.collections import PatchCollection

# %%
# %matplotlib inline

# %%
df.columns
# Out:
# Index(['barrels08', 'barrelsA08', 'charge120', 'charge240', 'city08',
#        'city08U', 'cityA08', 'cityA08U', 'cityCD', 'cityE', 'cityUF', 'co2',
#        'co2A', 'co2TailpipeAGpm', 'co2TailpipeGpm', 'comb08', 'comb08U',
#        'combA08', 'combA08U', 'combE', 'combinedCD', 'combinedUF', 'cylinders',
#        'displ', 'drive', 'engId', 'eng_dscr', 'feScore', 'fuelCost08',
#        'fuelCostA08', 'fuelType', 'fuelType1', 'ghgScore', 'ghgScoreA',
#        'highway08', 'highway08U', 'highwayA08', 'highwayA08U', 'highwayCD',
#        'highwayE', 'highwayUF', 'hlv', 'hpv', 'id', 'lv2', 'lv4', 'make',
#        'model', 'mpgData', 'phevBlended', 'pv2', 'pv4', 'range', 'rangeCity',
#        'rangeCityA', 'rangeHwy', 'rangeHwyA', 'trany', 'UCity', 'UCityA',
#        'UHighway', 'UHighwayA', 'VClass', 'year', 'youSaveSpend', 'guzzler',
#        'trans_dscr', 'tCharger', 'sCharger', 'atvType', 'fuelType2', 'rangeA',
#        'evMotor', 'mfrCode', 'c240Dscr', 'charge240b', 'c240bDscr',
#        'createdOn', 'modifiedOn', 'startStop', 'phevCity', 'phevHwy',
#        'phevComb'],
#       dtype='object')

# %%
"""Checking null values"""
df.isnull().sum()
# Out:
# barrels08         0
# barrelsA08        0
# charge120         0
# charge240         0
# city08            0
#               ...
# modifiedOn        0
# startStop     31689
# phevCity          0
# phevHwy           0
# phevComb          0
# Length: 83, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46024 entries, 0 to 46023
# Data columns (total 83 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   barrels08        46024 non-null  float64
#  1   barrelsA08       46024 non-null  float64
#  2   charge120        46024 non-null  float64
#  3   charge240        46024 non-null  float64
#  4   city08           46024 non-null  int64
#  5   city08U          46024 non-null  float64
#  6   cityA08          46024 non-null  int64
#  7   cityA08U         46024 non-null  float64
#  8   cityCD           46024 non-null  float64
#  9   cityE            46024 non-null  float64
#  10  cityUF           46024 non-null  float64
#  11  co2              46024 non-null  int64
#  12  co2A             46024 non-null  int64
#  13  co2TailpipeAGpm  46024 non-null  float64
#  14  co2TailpipeGpm   46024 non-null  float64
#  15  comb08           46024 non-null  int64
#  16  comb08U          46024 non-null  float64
#  17  combA08          46024 non-null  int64
#  18  combA08U         46024 non-null  float64
#  19  combE            46024 non-null  float64
#  20  combinedCD       46024 non-null  float64
#  21  combinedUF       46024 non-null  float64
#  22  cylinders        45537 non-null  float64
#  23  displ            45539 non-null  float64
#  24  drive            44838 non-null  object
#  25  engId            46024 non-null  int64
#  26  eng_dscr         28976 non-null  object
#  27  feScore          46024 non-null  int64
#  28  fuelCost08       46024 non-null  int64
#  29  fuelCostA08      46024 non-null  int64
#  30  fuelType         46024 non-null  object
#  31  fuelType1        46024 non-null  object
#  32  ghgScore         46024 non-null  int64
#  33  ghgScoreA        46024 non-null  int64
#  34  highway08        46024 non-null  int64
#  35  highway08U       46024 non-null  float64
#  36  highwayA08       46024 non-null  int64
#  37  highwayA08U      46024 non-null  float64
#  38  highwayCD        46024 non-null  float64
#  39  highwayE         46024 non-null  float64
#  40  highwayUF        46024 non-null  float64
#  41  hlv              46024 non-null  int64
#  42  hpv              46024 non-null  int64
#  43  id               46024 non-null  int64
#  44  lv2              46024 non-null  int64
#  45  lv4              46024 non-null  int64
#  46  make             46024 non-null  object
#  47  model            46024 non-null  object
#  48  mpgData          46017 non-null  object
#  49  phevBlended      46024 non-null  bool
#  50  pv2              46024 non-null  int64
#  51  pv4              46024 non-null  int64
#  52  range            46024 non-null  int64
#  53  rangeCity        46024 non-null  float64
#  54  rangeCityA       46024 non-null  float64
#  55  rangeHwy         46024 non-null  float64
#  56  rangeHwyA        46024 non-null  float64
#  57  trany            46013 non-null  object
#  58  UCity            46024 non-null  float64
#  59  UCityA           46024 non-null  float64
#  60  UHighway         46024 non-null  float64
#  61  UHighwayA        46024 non-null  float64
#  62  VClass           46024 non-null  object
#  63  year             46024 non-null  int64
#  64  youSaveSpend     46024 non-null  int64
#  65  guzzler          2701 non-null   object
#  66  trans_dscr       15044 non-null  object
#  67  tCharger         9575 non-null   object
#  68  sCharger         990 non-null    object
#  69  atvType          4678 non-null   object
#  70  fuelType2        1838 non-null   object
#  71  rangeA           1833 non-null   object
#  72  evMotor          1826 non-null   object
#  73  mfrCode          15216 non-null  object
#  74  c240Dscr         141 non-null    object
#  75  charge240b       46024 non-null  float64
#  76  c240bDscr        135 non-null    object
#  77  createdOn        46024 non-null  object
#  78  modifiedOn       46024 non-null  object
#  79  startStop        14335 non-null  object
#  80  phevCity         46024 non-null  int64
#  81  phevHwy          46024 non-null  int64
#  82  phevComb         46024 non-null  int64
# dtypes: bool(1), float64(32), int64(27), object(23)
# memory usage: 28.8+ MB

# %%
plt.hist(df['comb08'])
plt.xlabel('Combined Fuel Economy (MPG)')
plt.ylabel('Number of cars')
plt.title('Combined Fuel Economy (2000-2020)')
plt.show()

# %% [markdown]
# # Object Oriented API

# %%
fig, ax = plt.subplots()
ax.hist(df['comb08']);

# %%
fig, ax = plt.subplots()
ax.hist(df['comb08'])
ax.set_xlabel('Combined Fuel Economy (MPG)')
ax.set_ylabel('Number of cars')
ax.set_title('Combined Fuel Economy (2000-2020)')
#fig.show()
# Out:
# Text(0.5, 1.0, 'Combined Fuel Economy (2000-2020)')

# %%
fig, ax = plt.subplots()
ax.hist(df['comb08'])
ax.set(xlabel='Combined Fuel Economy (MPG)',
       ylabel='Number of cars',
       title='Combined Fuel Economy (2000-2020)');

# %%
fig, ax = plt.subplots()
ax.hist(df['comb08'], range=(10,50));

# %%
fig, ax = plt.subplots()
ax.hist(df['comb08'], range=(10,50), cumulative=True);

# %%
fig, ax = plt.subplots()
ax.hist(df['comb08'], range=(10,50), histtype='step', orientation='horizontal');

# %%
fig, ax = plt.subplots()
ax.hist(df['comb08'], range=(10,50), bins=5);

# %%
fig, ax = plt.subplots()
ax.hist(df['comb08'], range=(10,50), bins=100);

# %%
fig, ax = plt.subplots()
n, bins, patches = ax.hist(df['comb08'], range=(10,50));

# %%
n
# Out:
# array([ 2720., 10371., 15961.,  9505.,  4248.,  1620.,   521.,   252.,
#           85.,   103.])

# %%
bins
# Out:
# array([10., 14., 18., 22., 26., 30., 34., 38., 42., 46., 50.])

# %%
patches
# Out:
# <BarContainer object of 10 artists>

# %%
fig, (ax1, ax2) = plt.subplots(2)
ax1.hist(df['comb08'], range=(10,50))
ax2.hist(df['comb08'], range=(10,100));

# %%
fig, ax = plt.subplots()
ax.boxplot(df['comb08'], labels=['All'])
ax.set(title='MPG Distribution', ylabel='MPG for vehicles');

# %%
fig, ax = plt.subplots()
ax.boxplot(df['comb08'], labels=['All'], showfliers=False)
ax.set(title='MPG Distribution', ylabel='MPG for vehicles');

# %%
fig, (ax1, ax2) = plt.subplots(2)
ax1.hist(df['comb08'], range=(10,50))
ax1.set(title='Vehicle MPG', xlabel='Combined MPG', ylabel='Number of Cars')

ax2.boxplot(df['comb08'], labels=['All'], vert=False, showfliers=False)
ax2.set(ylabel='MPG for vehicles');

# %%
avg_by_year = df.groupby(['year'], as_index=False).agg({'fuelCost08': 'mean'}).round(2)
avg_by_year
# Out:
#     year  fuelCost08
# 0   1984     2806.31
# 1   1985     2822.66
# 2   1986     2836.03
# 3   1987     2890.34
# 4   1988     2866.02
# 5   1989     2924.41
# 6   1990     2928.11
# 7   1991     2999.25
# 8   1992     3000.09
# 9   1993     2951.69
# 10  1994     2966.70
# 11  1995     3013.19
# 12  1996     2856.40
# 13  1997     2894.82
# 14  1998     2865.33
# 15  1999     2873.53
# 16  2000     2921.79
# 17  2001     2944.18
# 18  2002     2983.03
# 19  2003     3040.28
# 20  2004     3029.10
# 21  2005     3039.11
# 22  2006     3061.23
# 23  2007     3057.77
# 24  2008     3060.03
# 25  2009     2922.57
# 26  2010     2834.81
# 27  2011     2816.25
# 28  2012     2763.91
# 29  2013     2669.87
# 30  2014     2660.32
# 31  2015     2600.70
# 32  2016     2532.45
# 33  2017     2531.98
# 34  2018     2549.81
# 35  2019     2542.22
# 36  2020     2573.25
# 37  2021     2585.40
# 38  2022     2534.38
# 39  2023     2515.19
# 40  2024     2792.31

# %%
mpg_model = smf.ols("fuelCost08 ~ year", data=avg_by_year).fit()

# %%
mpg_model.fittedvalues
# Out:
# 0     3019.952439
# 1     3010.487524
# 2     3001.022610
# 3     2991.557695
# 4     2982.092780
# 5     2972.627866
# 6     2963.162951
# 7     2953.698037
# 8     2944.233122
# 9     2934.768207
# 10    2925.303293
# 11    2915.838378
# 12    2906.373463
# 13    2896.908549
# 14    2887.443634
# 15    2877.978720
# 16    2868.513805
# 17    2859.048890
# 18    2849.583976
# 19    2840.119061
# 20    2830.654146
# 21    2821.189232
# 22    2811.724317
# 23    2802.259402
# 24    2792.794488
# 25    2783.329573
# 26    2773.864659
# 27    2764.399744
# 28    2754.934829
# 29    2745.469915
# 30    2736.005000
# 31    2726.540085
# 32    2717.075171
# 33    2707.610256
# 34    2698.145341
# 35    2688.680427
# 36    2679.215512
# 37    2669.750598
# 38    2660.285683
# 39    2650.820768
# 40    2641.355854
# dtype: float64

# %%
mpg_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             fuelCost08   R-squared:                       0.408
# Model:                            OLS   Adj. R-squared:                  0.393
# Method:                 Least Squares   F-statistic:                     26.89
# Date:                Mon, 06 Mar 2023   Prob (F-statistic):           6.96e-06
# Time:                        23:53:01   Log-Likelihood:                -259.25
# No. Observations:                  41   AIC:                             522.5
# Df Residuals:                      39   BIC:                             525.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    2.18e+04   3657.862      5.959      0.000    1.44e+04    2.92e+04
# year          -9.4649      1.825     -5.186      0.000     -13.157      -5.773
# ==============================================================================
# Omnibus:                        3.699   Durbin-Watson:                   0.247
# Prob(Omnibus):                  0.157   Jarque-Bera (JB):                2.312
# Skew:                           0.372   Prob(JB):                        0.315
# Kurtosis:                       2.105   Cond. No.                     3.39e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.39e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
fig, ax = plt.subplots()
ax.scatter(x=avg_by_year['year'], y=avg_by_year['fuelCost08'])
ax.plot(avg_by_year['year'], mpg_model.fittedvalues);

# %%
df_2010 = df.query('year >= 2010').copy()
avg_fuel_cost = df_2010['fuelCost08'].mean().round(0)
avg_fuel_cost
# Out:
# 2617.0
